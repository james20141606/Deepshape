# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ..
# Out:
# /Share/home/shibinbin/projects/Deepfold2

# %%
import h5py

# %%
with h5py.File('data/icSHAPE/Spitale_2015_invitro/scores/all', 'r') as f:
    names = f['name'][:]
    scores = f['/feature/scores'][:]
    rpkm = f['/meta/rpkm'][:]
print('fraction of nan: %f'%(float(np.isnan(scores).sum())/scores.shape[0]))
scores_avail = scores[np.logical_not(np.isnan(scores))]
# Out:
# fraction of nan: 0.276203

# %%
fig, ax = subplots(figsize=(16, 3))
ax.plot(np.where(np.isnan(scores), 0, scores)[:200])

# %%
print(np.percentile(scores_avail, 0.1), np.percentile(scores_avail, 99.9))
# Out:
# (-2.8362738966941832, 7.4799996852878063)

# %%
h = hist(scores_avail, bins=100, normed=True)

# %%
np.clip(scores, -3, 3)
# Out:
# array([ nan,  nan,  nan, ...,  nan,  nan,  nan])
