# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ..
# Out:
# /Share/home/shibinbin/projects/Deepfold2

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_table('reports/BaseDistributionByBin/icSHAPE/Spitale_2015_invitro.percentile.txt')
fig, ax = subplots(figsize=(15, 4))
xticklabels = ['%.2f'%a for a in df['percentile'].unique()]
x = np.arange(len(xticklabels))
for base in 'ATCG':
    sub_df = df[df['base'] == base]
    ax.plot(x, sub_df['fraction'], label=base)
ax.set_xticks(x)
ax.set_xticklabels(xticklabels)
ax.set_ylim(0, 1)
ax.set_xlabel('icSHAPE scores')
ax.set_ylabel('Fraction')
ax.legend()

# %%
df = pd.read_table('reports/BaseDistributionByBin/icSHAPE/Spitale_2015_invitro.value.txt')
fig, ax = subplots(figsize=(15, 4))
xticklabels = ['%.2f'%a for a in df['percentile'].unique()]
x = np.arange(len(xticklabels))
for base in 'ATCG':
    sub_df = df[df['base'] == base]
    ax.plot(x, sub_df['fraction'], label=base)
ax.set_xticks(x)
ax.set_xticklabels(xticklabels)
ax.set_ylim(0, 1)
ax.set_xlabel('icSHAPE scores')
ax.set_ylabel('Fraction')
ax.legend()
