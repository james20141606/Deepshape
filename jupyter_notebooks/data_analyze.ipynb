# %%
import numpy as np
import h5py
import pandas as pd

# %%
cd /home/chenxupeng/projects/deepshape/
# Out:
# /home/chenxupeng/projects/deepshape

# %%
result = np.loadtxt('result',dtype ="S")

# %%
a = np.ndarray([47,4]).astype('S')
for i in range(47):
    a[i][0]=result[i][0].split('_')[-2]
    a[i][1]=result[i][0].split('_')[-1]
    a[i][2:]=result[i][1:]

# %%
table = pd.DataFrame(a)

# %%
table.columns = ['coverage','percentile','train','test']
table.iloc[23]['coverage'] = 0.4
table.iloc[23]['percentile'] = 5

# %%
table
# Out:
#    coverage percentile  train   test
# 0       0.1         10  75033  18291
# 1       0.1         15  75148  18902
# 2       0.1         20  75520  18784
# 3       0.1         25  75094  19354
# 4       0.1         30  76641  17862
# 5       0.1          5  72842  18203
# 6       0.2         10  68182  16356
# 7       0.2         15  71724  18122
# 8       0.2         20  74262  18071
# 9       0.2         25  74875  18805
# 10      0.2         30  74989  19061
# 11      0.2          5  59332  15221
# 12      0.3         10  50806  12157
# 13      0.3         15  61015  14980
# 14      0.3         20  67223  17378
# 15      0.3         25  72787  18310
# 16      0.3         30  75019  18431
# 17      0.3          5  37789   9571
# 18      0.4         10  27143   6650
# 19      0.4         15  39236   9828
# 20      0.4         20  51452  13154
# 21      0.4         25  64596  16941
# 22      0.4         30  73513  18172
# 23      0.4          5   5730   1525
# ...
