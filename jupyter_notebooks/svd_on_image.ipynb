# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scipy.misc

# %%
imshow(scipy.misc.face(True), cmap=cm.Greys_r)

# %%
X = scipy.misc.face(True).astype(np.float64)
U, S, V = numpy.linalg.svd(X, full_matrices=False)

# %%
print U.shape, S.shape, V.shape, X.shape
# Out:
# (768, 768) (768,) (768, 1024) (768, 1024)

# %%
imshow(U.dot(np.diag(S)).dot(V), cmap=cm.Greys_r)

# %%
X.shape

# %%
i = 200
j = 201
imshow(U[:, i:j].dot(np.diag(S[i:j])).dot(V[i:j, :]), cmap=cm.Greys_r)

# %%
plot(U[:, 200])

# %%
print U[i, :].shape, V[i, :].shape
print U[:, i].shape, V[:, i].shape
# Out:
# (768,) (1024,)
# (768,) (768,)

# %%
fig, ax = plt.subplots(figsize=(18, 3))
ax.plot(S)

# %%
np.sum(S > 1000)
# Out:
# 120
