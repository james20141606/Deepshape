# %%
cd /home/chenxupeng/projects/deepshape/
# Out:
# /home/chenxupeng/projects/deepshape

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import argparse, sys, os, errno
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
from tqdm import tqdm
import keras as K
import seaborn as sns
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from unet_128_model_row_column import *
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
import tensorflow as tf
import matplotlib.pyplot as plt
# %pylab inline
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" # so the IDs match nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.99
set_session(tf.Session(config=config))
from keras.models import load_model
from keras.utils.generic_utils import get_custom_objects
# Out:
# Using TensorFlow backend.
# Populating the interactive namespace from numpy and matplotlib

# %%
def prepare_data(numbers):
    '''
        use different seqs
    '''
    seqs = {}
    with h5py.File('data/new/Spitale_2015_invivo_CDS_0.1') as f:
        for i in range(numbers):
            seqs[i] = f['X_train'][128*i]
    return seqs
def convert_to_image(x):
    m = (np.repeat(x, 4, axis=1)[np.newaxis, :, :]*np.tile(x, 4)[:, np.newaxis, :])
    return m
def Model():
    #为转成十六通道的图片预测shape做准备
    model = UNET_128()
    optim = Adam()
    model.compile(optimizer=optim, loss=CrossEntropyLoss(model,10), metrics=[binary_accuracy_with_nan,binary_crossentropy_with_nan,MSE(model)])
    loss=CrossEntropyLoss(model,10)
    model = load_model('output/unet_for_mutation_map.hdf5',custom_objects = {"CrossEntropyLoss": loss,\
                                                                            'binary_accuracy_with_nan':binary_accuracy_with_nan,\
                                                                            'binary_crossentropy_with_nan':binary_crossentropy_with_nan,\
                                                                            'MSE':MSE(model)})
    return model
def generate_mutation_map(seq):
    '''seq shape: 128*4
    将一条序列每个位点突变
    return 384*128*4
    '''
    length = 128
    #需要生成的 1的位置
    mutated = np.ndarray([length*3,length,4]).astype('int')
    for j in range(length):
        position = np.setdiff1d(np.array([0,1,2,3]),np.where(seq[j]==1)[0][0])
        for i in range(3):
            a = np.zeros(4).astype('int')
            array = np.copy(seq)
            a[position[i]] = 1
            array[j] = a
            mutated[j*3+i] = array
    images_mutated = np.ndarray([length*3,length,length,16]).astype('int')
    for i in range(length*3):
        images_mutated[i] = convert_to_image(mutated[i])
    images_origin = convert_to_image(seq)
    model = Model()
    predict_origin = model.predict(images_origin.reshape(1,128,128,16))[0][:128]
    predict_mutated = model.predict(images_mutated)[:,:128]
    mutation_map = np.ndarray([128*3,128])
    for i in range(128*3):
        mutation_map[i] =  predict_origin - predict_mutated[i]
    return mutation_map
def mutiple_mutation_maps(seqs,numbers):
    '''
        output many seqs mutation maps
    '''
    mutation_map = {}
    for i in tqdm(range(numbers)):
        mutation_map[i] = generate_mutation_map(seqs[i])
    mutation_map_ = np.array([val for (key,val) in mutation_map.iteritems()],dtype)
    mutation_map_ = mutation_map_.astype('float')
    return mutation_map_
def convert_to_cube(map):
    cube_map = np.ndarray([384,384])
    for i in range(128):
        cube_map[:,3*i] = map[:,i]
        cube_map[:,3*i+1] = map[:,i]
        cube_map[:,3*i+2] = map[:,i]
    return cube_map
def multi_cube_map(mutation_map,numbers):
    '''generate different seqs' cube array '''
    cube_map = {}
    for i in range(numbers):
        cube_map[i] = convert_to_cube(mutation_map[i])
    return cube_map

# %%
def generate_boxplot(mutationmap):
    new_map = np.ndarray([384,256])
    for i in range(128):
        new_map[3*i] = np.concatenate((np.concatenate((np.zeros(128-i),mutationmap[3*i])),np.zeros(i)))
        new_map[3*i+1] = np.concatenate((np.concatenate((np.zeros(128-i),mutationmap[3*i+1])),np.zeros(i)))
        new_map[3*i+2] = np.concatenate((np.concatenate((np.zeros(128-i),mutationmap[3*i+2])),np.zeros(i)))
    return new_map
def generate_mutiple_boxplot(mutationmaps,numbers):
    '''
        numbers: 序列数 map数
        mutationmaps:number个数个mutation map在一起
    '''
    new_map = np.ndarray([numbers,384,256])
    for i in range(numbers):
        new_map[i] = generate_boxplot(mutationmaps[i])
    return new_map

# %%
def generate_images(seq):
    '''seq shape: 128*4
    将一条序列每个位点突变
    return 384*128*4
    '''
    length = 128
    #需要生成的 1的位置
    mutated = np.ndarray([length*3,length,4]).astype('int')
    for j in range(length):
        position = np.setdiff1d(np.array([0,1,2,3]),np.where(seq[j]==1)[0][0])
        for i in range(3):
            a = np.zeros(4).astype('int')
            array = np.copy(seq)
            a[position[i]] = 1
            array[j] = a
            mutated[j*3+i] = array
    images_mutated = np.ndarray([length*3,length,length,16]).astype('int')
    for i in range(length*3):
        images_mutated[i] = convert_to_image(mutated[i])
    images_origin = convert_to_image(seq)
    return images_mutated,images_origin

# %%
seqs = prepare_data(100)

# %%
img_mut,img_ori = generate_images(seqs[0])

# %%
img_mut.shape
# Out:
# (384, 128, 128, 16)

# %%
model = Model()
inp = model.input                                           # input placeholder
outputs = [layer.output for layer in model.layers]          # all layer outputs
functor = K.function([inp]+ [K.learning_phase()], outputs ) # evaluation function

# %%
def produce_cnn_output(imgmut,imgori,counts):
    '''
        input a seq's mutate 384 and origin one image
        output the last cnn map of mutate and origin
        counts specify the numbers of mutate pictures \ 
        in order to avoid memory error
    '''
    inter = 384/counts
    imgmt = np.ndarray([counts,128,128,16])
    for i in range(counts):
        imgmt[i] = imgmut[i*inter]
    layer_outs_mut = functor([imgmt, 1.])
    layer_outs_ori = functor([imgori.reshape(1,128,128,16), 1.])
    dot_list= np.array([i*inter/3 for i in range(counts)]).astype('int')
    return layer_outs_mut[94],layer_outs_ori[94],dot_list

# %%
cnn_mut,cnn_ori,dotlist = produce_cnn_output(img_mut,img_ori,16)

# %% [markdown]
# #imshow 查看输出
# fig, ax = plt.subplots(4, 4, figsize=(20, 20))
# for i in range(4):
#     for j in range(4):
#         ax[j,i].matshow(cnn_mut[i*4+j][:,:,0],cmap=cm.RdBu_r)

# %%
def mutate_and_map_2d(cnn_mut,cnn_ori):
    '''
        input: cnn_mut and cnn_ori of 94th layer
        output: mutate map
    '''
    counts= cnn_mut.shape[0]
    mutate_map = np.ndarray([counts,128,128])
    mutate_map_noabs = np.ndarray([counts,128,128])
    for i in range(counts):
        mutate_map[i] = np.abs(cnn_mut[i] - cnn_ori).reshape(128,128)
        mutate_map_noabs[i] = np.abs(cnn_mut[i] - cnn_ori).reshape(128,128)
    return mutate_map,mutate_map_noabs

# %%
mutate_map,mutate_map_noabs = mutate_and_map_2d(cnn_mut,cnn_ori)

# %%
dotlist
# Out:
# array([  0,   8,  16,  24,  32,  40,  48,  56,  64,  72,  80,  88,  96,
#        104, 112, 120])

# %%
#imshow 查看输出  
fig, ax = plt.subplots(4, 4, figsize=(20, 20))
for i in range(4):
    for j in range(4):
        ax[j,i].matshow(mutate_map[i*4+j],cmap=cm.RdBu_r)
        ax[j,i].scatter(dotlist[i*4+j],dotlist[i*4+j],marker='*',c = 'w',s = 200)
        ax[j,i].set_xlim(0,128)
        ax[j,i].set_ylim(128,0)

# %% [markdown]
# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot
#
# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='png'))

# %%
#model.summary()

# %%
#查看每层输出
def produce_every_layers(imgmut,imgori):
    '''
        input a seq's mutate 384 and origin one image
        output the last cnn map of mutate and origin
        counts specify the numbers of mutate pictures \ 
        in order to avoid memory error
    '''

    layer_outs_mut = functor([imgmut, 1.])
    layer_outs_ori = functor([imgori.reshape(1,128,128,16), 1.])
    return layer_outs_mut,layer_outs_ori

# %%
layers_mut,layers_ori = produce_every_layers(img_mut[31:32],img_ori)

# %%
layers_mut[1].shape[2]
# Out:
# 128

# %%
def draw_each_layer(layer_index,layers_mut,layers_ori):
    fig, ax = plt.subplots(4, 4, figsize=(20, 20))
    for i in range(4):
        for j in range(4):
            ax[j,i].matshow(layers_mut[layer_index][0,:,:,i*4+j] -layers_ori[layer_index][0,:,:,i*4+j] ,cmap=cm.RdBu_r)
            ax[j,i].scatter(11,11,marker='*',c = 'w',s = 200)
            figshape = layers_mut[layer_index].shape[2]
            ax[j,i].set_xlim(0,figshape)
            ax[j,i].set_ylim(figshape,0)
    fig.savefig('mutation/layers_output/layer_'+str(layer_index)+'_mutate_map')

# %% [markdown]
# for i in np.arange(1,92):
#     draw_each_layer(i,layers_mut,layers_ori)

# %%
layers_mut[1].shape
# Out:
# (1, 128, 128, 32)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 16) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 4640        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 256)    0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 512)    2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 512)    2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 512)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 512)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 512)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 1024)   9438208     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 4, 4, 1024)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 1024)   0           dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 1536)   0           up_sampling2d_1[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 512)    7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 512)    2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 512)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 512)    2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 512)    2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 512)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 512)  0           dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 768)  0           up_sampling2d_2[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 256)  1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 256)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 256)  0           dropout_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 384)  0           up_sampling2d_3[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 128)  442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 128)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 128)  0           dropout_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 192)  0           up_sampling2d_4[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 64)   110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64, 64, 64)   0           activation_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 64) 0           dropout_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 96) 0           up_sampling2d_5[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 27680       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 128, 128, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 128, 128, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 1)  33          activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 1)  4           conv2d_23[0][0]
# __________________________________________________________________________________________________
# last_activation (Activation)    (None, 128, 128, 1)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128)          0           last_activation[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 128)          0           last_activation[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 128)          0           lambda_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 128)          0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128)          0           reshape_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 128)          0           reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 256)          0           lambda_2[0][0]
#                                                                  lambda_4[0][0]
# ==================================================================================================
# Total params: 31,470,501
# Trainable params: 31,458,467
# Non-trainable params: 12,034
# __________________________________________________________________________________________________

# %%
fig, ax = plt.subplots(1 ,figsize=(8,8))
    ax.matshow(layers_ori[94][0,:,:,0],cmap=cm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-c8fadc664a0d> in <module>()
#       1 fig, ax = plt.subplots(1 ,figsize=(8,8))
# ----> 2 ax.matshow(layers_ori[94][0,:,:,0],cmap=cm.np)
#
# /home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in matshow(self, Z, **kwargs)
#    7337               'aspect': 'equal'}          # (already the imshow default)
#    7338         kw.update(kwargs)
# -> 7339         im = self.imshow(Z, **kw)
#    7340         self.title.set_y(1.05)
#    7341         self.xaxis.tick_top()
#
# /home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5127         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5128                               filternorm=filternorm, filterrad=filterrad,
# -> 5129                               resample=resample, **kwargs)
#    5130
#    5131         im.set_data(X)
#
# /home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/matplotlib/image.pyc in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     774             filterrad=filterrad,
#     775             resample=resample,
# --> 776             **kwargs
#     777         )
#     778
#
# /home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/matplotlib/image.pyc in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     223         """
#     224         martist.Artist.__init__(self)
# --> 225         cm.ScalarMappable.__init__(self, norm, cmap)
#     226         self._mouseover = True
#     227         if origin is None:
#
# /home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/matplotlib/cm.pyc in __init__(self, norm, cmap)
#     202         self.norm = norm
#     203         #: The Colormap instance of this ScalarMappable.
# --> 204         self.cmap = get_cmap(cmap)
#     205         #: The last colorbar associated with this ScalarMappable. May be None.
#     206         self.colorbar = None
#
# /home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/matplotlib/cm.pyc in get_cmap(name, lut)
#     167         raise ValueError(
#     168             "Colormap %s is not recognized. Possible values are: %s"
# --> 169             % (name, ', '.join(sorted(cmap_d))))
#     170
#     171
#
# ValueError: Colormap <module 'numpy' from '/home/chenxupeng/apps/anaconda2/lib/python2.7/site-packages/numpy/__init__.pyc'> is not recognized. Possible values are: Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Vega10, Vega10_r, Vega20, Vega20_r, Vega20b, Vega20b_r, Vega20c, Vega20c_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spectral, spectral_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r
